# %% [markdown]
# <a href="https://colab.research.google.com/github/Parths131/mumbai-air-pollution/blob/main/Airport_pollution_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9b5b1c8d-e60b-4660-9a20-9d3037a9d302" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9b5b1c8d-e60b-4660-9a20-9d3037a9d302">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7aec3f4f-4556-4387-a512-03647ca93048" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7aec3f4f-4556-4387-a512-03647ca93048">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
df = pd.read_csv(io.BytesIO(uploaded['airport-all.csv']))

# %%
df.head()
# Out:
#           From Date           To Date PM2.5  PM10    NO   NO2   NOx   NH3  \
# 0  01-01-2019 00:00  02-01-2019 00:00  None  None  None  None  None  None
# 1  02-01-2019 00:00  03-01-2019 00:00  None  None  None  None  None  None
# 2  03-01-2019 00:00  04-01-2019 00:00  None  None  None  None  None  None
# 3  04-01-2019 00:00  05-01-2019 00:00  None  None  None  None  None  None
# 4  05-01-2019 00:00  06-01-2019 00:00  None  None  None  None  None  None
#
#     SO2    CO  ... Toluene Eth-Benzene MP-Xylene    RH    WS    WD    SR  \
# 0  None  None  ...    None        None      None  None  None  None  None
# 1  None  None  ...    None        None      None  None  None  None  None
# 2  None  None  ...    None        None      None  None  None  None  None
# 3  None  None  ...    None        None      None  None  None  None  None
# 4  None  None  ...    None        None      None  None  None  None  None
#
#      BP Xylene    AT
# 0  None   None  None
# 1  None   None  None
# ...

# %%
df.isnull().sum()
# Out:
# From Date      0
# To Date        0
# PM2.5          0
# PM10           0
# NO             0
# NO2            0
# NOx            0
# NH3            0
# SO2            0
# CO             0
# Ozone          0
# Benzene        0
# Toluene        0
# Eth-Benzene    0
# MP-Xylene      0
# RH             0
# WS             0
# WD             0
# SR             0
# BP             0
# Xylene         0
# AT             0
# dtype: int64

# %%
df.shape
# Out:
# (1535, 22)

# %%
df.isnull()
# Out:
#       From Date  To Date  PM2.5   PM10     NO    NO2    NOx    NH3    SO2  \
# 0         False    False  False  False  False  False  False  False  False
# 1         False    False  False  False  False  False  False  False  False
# 2         False    False  False  False  False  False  False  False  False
# 3         False    False  False  False  False  False  False  False  False
# 4         False    False  False  False  False  False  False  False  False
# ...         ...      ...    ...    ...    ...    ...    ...    ...    ...
# 1530      False    False  False  False  False  False  False  False  False
# 1531      False    False  False  False  False  False  False  False  False
# 1532      False    False  False  False  False  False  False  False  False
# 1533      False    False  False  False  False  False  False  False  False
# 1534      False    False  False  False  False  False  False  False  False
#
#          CO  ...  Toluene  Eth-Benzene  MP-Xylene     RH     WS     WD     SR  \
# ...

# %%
df.replace(to_replace='None', value='NaN')
# Out:
#              From Date           To Date  PM2.5    PM10      NO    NO2  \
# 0     01-01-2019 00:00  02-01-2019 00:00    NaN     NaN     NaN    NaN
# 1     02-01-2019 00:00  03-01-2019 00:00    NaN     NaN     NaN    NaN
# 2     03-01-2019 00:00  04-01-2019 00:00    NaN     NaN     NaN    NaN
# 3     04-01-2019 00:00  05-01-2019 00:00    NaN     NaN     NaN    NaN
# 4     05-01-2019 00:00  06-01-2019 00:00    NaN     NaN     NaN    NaN
# ...                ...               ...    ...     ...     ...    ...
# 1530  11-03-2023 00:00  12-03-2023 00:00  49.96  200.36  165.82  50.05
# 1531  12-03-2023 00:00  13-03-2023 00:00  60.31   216.5  159.86  53.33
# 1532  13-03-2023 00:00  14-03-2023 00:00  66.62  219.94  116.92   47.7
# 1533  14-03-2023 00:00  15-03-2023 00:00  59.81  203.86   84.85  50.99
# 1534  15-03-2023 00:00  15-03-2023 00:00     36     155   118.6   42.7
#
#          NOx    NH3   SO2    CO  ... Toluene Eth-Benzene MP-Xylene     RH  \
# ...

# %%
df.isnull().sum()
# Out:
# From Date      0
# To Date        0
# PM2.5          0
# PM10           0
# NO             0
# NO2            0
# NOx            0
# NH3            0
# SO2            0
# CO             0
# Ozone          0
# Benzene        0
# Toluene        0
# Eth-Benzene    0
# MP-Xylene      0
# RH             0
# WS             0
# WD             0
# SR             0
# BP             0
# Xylene         0
# AT             0
# dtype: int64

# %%
df
# Out:
#              From Date           To Date  PM2.5    PM10      NO    NO2  \
# 0     01-01-2019 00:00  02-01-2019 00:00   None    None    None   None
# 1     02-01-2019 00:00  03-01-2019 00:00   None    None    None   None
# 2     03-01-2019 00:00  04-01-2019 00:00   None    None    None   None
# 3     04-01-2019 00:00  05-01-2019 00:00   None    None    None   None
# 4     05-01-2019 00:00  06-01-2019 00:00   None    None    None   None
# ...                ...               ...    ...     ...     ...    ...
# 1530  11-03-2023 00:00  12-03-2023 00:00  49.96  200.36  165.82  50.05
# 1531  12-03-2023 00:00  13-03-2023 00:00  60.31   216.5  159.86  53.33
# 1532  13-03-2023 00:00  14-03-2023 00:00  66.62  219.94  116.92   47.7
# 1533  14-03-2023 00:00  15-03-2023 00:00  59.81  203.86   84.85  50.99
# 1534  15-03-2023 00:00  15-03-2023 00:00     36     155   118.6   42.7
#
#          NOx    NH3   SO2    CO  ... Toluene Eth-Benzene MP-Xylene     RH  \
# ...

# %%
df = df.replace(to_replace='None', value=np.nan)

# %%
df.isnull().sum()
# Out:
# From Date         0
# To Date           0
# PM2.5           224
# PM10            199
# NO              175
# NO2             178
# NOx             178
# NH3             181
# SO2             170
# CO              174
# Ozone           175
# Benzene         185
# Toluene        1535
# Eth-Benzene     213
# MP-Xylene       204
# RH              194
# WS              194
# WD              194
# SR             1350
# BP              688
# Xylene         1535
# AT              196
# dtype: int64

# %%
df.dtypes
# Out:
# From Date       object
# To Date         object
# PM2.5           object
# PM10            object
# NO              object
# NO2             object
# NOx             object
# NH3             object
# SO2             object
# CO              object
# Ozone           object
# Benzene         object
# Toluene        float64
# Eth-Benzene     object
# MP-Xylene       object
# RH              object
# WS              object
# WD              object
# SR              object
# BP              object
# Xylene         float64
# AT              object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1535 entries, 0 to 1534
# Data columns (total 22 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   From Date    1535 non-null   object
#  1   To Date      1535 non-null   object
#  2   PM2.5        1311 non-null   object
#  3   PM10         1336 non-null   object
#  4   NO           1360 non-null   object
#  5   NO2          1357 non-null   object
#  6   NOx          1357 non-null   object
#  7   NH3          1354 non-null   object
#  8   SO2          1365 non-null   object
#  9   CO           1361 non-null   object
#  10  Ozone        1360 non-null   object
#  11  Benzene      1350 non-null   object
#  12  Toluene      0 non-null      float64
#  13  Eth-Benzene  1322 non-null   object
#  14  MP-Xylene    1331 non-null   object
#  15  RH           1341 non-null   object
#  16  WS           1341 non-null   object
#  17  WD           1341 non-null   object
# ...

# %%
df = df.drop(['To Date'], axis=1)

# %%
df['From Date'] = pd.to_datetime(df['From Date'])

# %%
df.dtypes
# Out:
# From Date      datetime64[ns]
# PM2.5                  object
# PM10                   object
# NO                     object
# NO2                    object
# NOx                    object
# NH3                    object
# SO2                    object
# CO                     object
# Ozone                  object
# Benzene                object
# Toluene               float64
# Eth-Benzene            object
# MP-Xylene              object
# RH                     object
# WS                     object
# WD                     object
# SR                     object
# BP                     object
# Xylene                float64
# AT                     object
# dtype: object

# %%
df[['PM2.5','PM10','NO','NO2','NOx','NH3','SO2','CO','Ozone','Benzene','Toluene','Eth-Benzene','MP-Xylene','RH','WS','WD','SR','BP','Xylene','AT']] = df[['PM2.5','PM10','NO','NO2','NOx','NH3','SO2','CO','Ozone','Benzene','Toluene','Eth-Benzene','MP-Xylene','RH','WS','WD','SR','BP','Xylene','AT']].astype(float)

# %%
df.dtypes
# Out:
# From Date      datetime64[ns]
# PM2.5                 float64
# PM10                  float64
# NO                    float64
# NO2                   float64
# NOx                   float64
# NH3                   float64
# SO2                   float64
# CO                    float64
# Ozone                 float64
# Benzene               float64
# Toluene               float64
# Eth-Benzene           float64
# MP-Xylene             float64
# RH                    float64
# WS                    float64
# WD                    float64
# SR                    float64
# BP                    float64
# Xylene                float64
# AT                    float64
# dtype: object

# %%
sns.lineplot(data=df, x='From Date', y='PM2.5')
# Out:
# <Axes: xlabel='From Date', ylabel='PM2.5'>

# %%
df
# Out:
#       From Date  PM2.5    PM10      NO    NO2     NOx    NH3   SO2    CO  \
# 0    2019-01-01    NaN     NaN     NaN    NaN     NaN    NaN   NaN   NaN
# 1    2019-02-01    NaN     NaN     NaN    NaN     NaN    NaN   NaN   NaN
# 2    2019-03-01    NaN     NaN     NaN    NaN     NaN    NaN   NaN   NaN
# 3    2019-04-01    NaN     NaN     NaN    NaN     NaN    NaN   NaN   NaN
# 4    2019-05-01    NaN     NaN     NaN    NaN     NaN    NaN   NaN   NaN
# ...         ...    ...     ...     ...    ...     ...    ...   ...   ...
# 1530 2023-11-03  49.96  200.36  165.82  50.05  215.86  52.54  8.58  2.02
# 1531 2023-12-03  60.31  216.50  159.86  53.33  213.18  51.41  8.50  2.07
# 1532 2023-03-13  66.62  219.94  116.92  47.70  164.61  42.84  8.53  2.34
# 1533 2023-03-14  59.81  203.86   84.85  50.99  135.84  32.06  8.61  1.93
# 1534 2023-03-15  36.00  155.00  118.60  42.70  161.30  32.93  8.73  1.81
#
#       Ozone  ...  Toluene  Eth-Benzene  MP-Xylene     RH    WS      WD  SR  \
# ...

# %%
pm2_df = df[["From Date", "PM2.5"]]

# %%
pm2_df
# Out:
#       From Date  PM2.5
# 0    2019-01-01    NaN
# 1    2019-02-01    NaN
# 2    2019-03-01    NaN
# 3    2019-04-01    NaN
# 4    2019-05-01    NaN
# ...         ...    ...
# 1530 2023-11-03  49.96
# 1531 2023-12-03  60.31
# 1532 2023-03-13  66.62
# 1533 2023-03-14  59.81
# 1534 2023-03-15  36.00
#
# [1535 rows x 2 columns]

# %%
pm2_df.dropna()
# Out:
#       From Date  PM2.5
# 154  2019-04-06  14.50
# 156  2019-06-06  14.96
# 157  2019-07-06  13.36
# 158  2019-08-06  15.54
# 159  2019-09-06  15.31
# ...         ...    ...
# 1530 2023-11-03  49.96
# 1531 2023-12-03  60.31
# 1532 2023-03-13  66.62
# 1533 2023-03-14  59.81
# 1534 2023-03-15  36.00
#
# [1311 rows x 2 columns]

# %%
pm2_df['From Date'].dt.weekofyear
# Out:
# <ipython-input-31-7bcd74847275>:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   pm2_df['From Date'].dt.weekofyear
# 154     14
# 156     23
# 157     27
# 158     32
# 159     36
#         ..
# 1530    44
# 1531    48
# 1532    11
# 1533    11
# 1534    11
# Name: From Date, Length: 1311, dtype: int64
